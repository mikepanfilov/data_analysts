# %% [markdown]
# ## Исследование надёжности заёмщиков
#
# Заказчик — кредитный отдел банка. Нужно разобраться, влияет ли семейное положение и количество детей клиента на факт погашения кредита в срок. Входные данные от банка — статистика о платёжеспособности клиентов.
#
# Результаты исследования будут учтены при построении модели **кредитного скоринга** — специальной системы, которая оценивает способность потенциального заёмщика вернуть кредит банку.

# %% [markdown]
# ### Шаг 1. Откройте файл с данными и изучите общую информацию.

# %%
import pandas as pd
data = pd.read_csv('dataset/data.csv', index_col=0)
data.head(5)
# Out:
#    children  days_employed  dob_years education  education_id  \
# 0         1   -8437.673028         42    высшее             0
# 1         1   -4024.803754         36   среднее             1
# 2         0   -5623.422610         33   Среднее             1
# 3         3   -4124.747207         32   среднее             1
# 4         0  340266.072047         53   среднее             1
#
#       family_status  family_status_id gender income_type  debt   total_income  \
# 0   женат / замужем                 0      F   сотрудник     0  253875.639453
# 1   женат / замужем                 0      F   сотрудник     0  112080.014102
# 2   женат / замужем                 0      M   сотрудник     0  145885.952297
# 3   женат / замужем                 0      M   сотрудник     0  267628.550329
# 4  гражданский брак                 1      F   пенсионер     0  158616.077870
#
#                       purpose
# 0               покупка жилья
# 1     приобретение автомобиля
# 2               покупка жилья
# 3  дополнительное образование
# 4             сыграть свадьбу

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21525 non-null  int64
#  1   days_employed     19351 non-null  float64
#  2   dob_years         21525 non-null  int64
#  3   education         21525 non-null  object
#  4   education_id      21525 non-null  int64
#  5   family_status     21525 non-null  object
#  6   family_status_id  21525 non-null  int64
#  7   gender            21525 non-null  object
#  8   income_type       21525 non-null  object
#  9   debt              21525 non-null  int64
#  10  total_income      19351 non-null  float64
#  11  purpose           21525 non-null  object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.1+ MB

# %% [markdown]
# ### Вывод

# %% [markdown]
# * В представленной таблице в столбцах days_employed и total_income имеются пустые значения.
# * Так же бросается в глаза что столбец days_emloyed имеют вещественные и отрицательные значения.
# * В столбце education имеются различия в регистре.
# * Столбец total_income так же имеет вещественные значения.

# %% [markdown]
# ### Шаг 2. Предобработка данных

# %% [markdown]
# ### Обработка пропусков

# %%
data = data.fillna(0)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21525 non-null  int64
#  1   days_employed     21525 non-null  float64
#  2   dob_years         21525 non-null  int64
#  3   education         21525 non-null  object
#  4   education_id      21525 non-null  int64
#  5   family_status     21525 non-null  object
#  6   family_status_id  21525 non-null  int64
#  7   gender            21525 non-null  object
#  8   income_type       21525 non-null  object
#  9   debt              21525 non-null  int64
#  10  total_income      21525 non-null  float64
#  11  purpose           21525 non-null  object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.1+ MB

# %% [markdown]
#  Пропуски заполним нулевыми значениями для безошибочного преобразования в целочисленный формат.

# %%
data['days_employed'] = abs(data['days_employed'].astype('int'))
data.head()
# Out:
#    children  days_employed  dob_years education  education_id  \
# 0         1           8437         42    высшее             0
# 1         1           4024         36   среднее             1
# 2         0           5623         33   Среднее             1
# 3         3           4124         32   среднее             1
# 4         0         340266         53   среднее             1
#
#       family_status  family_status_id gender income_type  debt   total_income  \
# 0   женат / замужем                 0      F   сотрудник     0  253875.639453
# 1   женат / замужем                 0      F   сотрудник     0  112080.014102
# 2   женат / замужем                 0      M   сотрудник     0  145885.952297
# 3   женат / замужем                 0      M   сотрудник     0  267628.550329
# 4  гражданский брак                 1      F   пенсионер     0  158616.077870
#
#                       purpose
# 0               покупка жилья
# 1     приобретение автомобиля
# 2               покупка жилья
# 3  дополнительное образование
# 4             сыграть свадьбу

# %% [markdown]
# Избавились от знака в общем трудовом стаже ('days_employed') и преобразовали в целочисленный вид.

# %%
data['total_income']=data['total_income'].round(2)
data.head()
# Out:
#    children  days_employed  dob_years education  education_id  \
# 0         1           8437         42    высшее             0
# 1         1           4024         36   среднее             1
# 2         0           5623         33   Среднее             1
# 3         3           4124         32   среднее             1
# 4         0         340266         53   среднее             1
#
#       family_status  family_status_id gender income_type  debt  total_income  \
# 0   женат / замужем                 0      F   сотрудник     0     253875.64
# 1   женат / замужем                 0      F   сотрудник     0     112080.01
# 2   женат / замужем                 0      M   сотрудник     0     145885.95
# 3   женат / замужем                 0      M   сотрудник     0     267628.55
# 4  гражданский брак                 1      F   пенсионер     0     158616.08
#
#                       purpose
# 0               покупка жилья
# 1     приобретение автомобиля
# 2               покупка жилья
# 3  дополнительное образование
# 4             сыграть свадьбу

# %%
data[data['total_income']<0].count()
# Out:
# children            0
# days_employed       0
# dob_years           0
# education           0
# education_id        0
# family_status       0
# family_status_id    0
# gender              0
# income_type         0
# debt                0
# total_income        0
# purpose             0
# dtype: int64

# %% [markdown]
# В столбце ежемесячного дохода ('total_income'):
# * округлили денежное выражение до двух знаков после запятой
# * проверили что нет отрицательных зарплат

# %%
data['children'].value_counts()
# Out:
#  0     14149
#  1      4818
#  2      2055
#  3       330
#  20       76
# -1        47
#  4        41
#  5         9
# Name: children, dtype: int64

# %% [markdown]
# Обнаружено отрицательное количество детей и выброс в 20 детей (в современном мире такое количество кажется не возможным, если только эти люди не организовали домашний приют и не оформили всех детей на себя).

# %%
young_dob = data[data['dob_years']<18]
young_dob['dob_years'].value_counts()
# Out:
# 0    101
# Name: dob_years, dtype: int64

# %% [markdown]
# Проверено количество заемщиков, которые не имеют законного права брать кредит и выявлены позиции с нулевым возрастом клиента.

# %%
data['education'].value_counts()
# Out:
# среднее                13750
# высшее                  4718
# СРЕДНЕЕ                  772
# Среднее                  711
# неоконченное высшее      668
# ВЫСШЕЕ                   274
# Высшее                   268
# начальное                250
# Неоконченное высшее       47
# НЕОКОНЧЕННОЕ ВЫСШЕЕ       29
# НАЧАЛЬНОЕ                 17
# Начальное                 15
# ученая степень             4
# УЧЕНАЯ СТЕПЕНЬ             1
# Ученая степень             1
# Name: education, dtype: int64

# %%
data['education'] = data['education'].str.lower()
data['education'].value_counts()
# Out:
# среднее                15233
# высшее                  5260
# неоконченное высшее      744
# начальное                282
# ученая степень             6
# Name: education, dtype: int64

# %% [markdown]
# В графе образование выявлены нарушения регистра и выполнено преобразование.

# %%
data['education_id'].value_counts()
# Out:
# 1    15233
# 0     5260
# 2      744
# 3      282
# 4        6
# Name: education_id, dtype: int64

# %%
data['family_status'].value_counts()
data['family_status'] = data['family_status'].str.lower()
data['family_status'].value_counts()
# Out:
# женат / замужем          12380
# гражданский брак          4177
# не женат / не замужем     2813
# в разводе                 1195
# вдовец / вдова             960
# Name: family_status, dtype: int64

# %% [markdown]
# Приводим все к нижнему регистру на радость внутреннему перфекционисту.

# %%
data['family_status_id'].value_counts()
# Out:
# 0    12380
# 1     4177
# 4     2813
# 3     1195
# 2      960
# Name: family_status_id, dtype: int64

# %%
data['gender'].value_counts()
# Out:
# F      14236
# M       7288
# XNA        1
# Name: gender, dtype: int64

# %%
data[data['gender'] == 'XNA']
# Out:
#        children  days_employed  dob_years            education  education_id  \
# 10701         0           2358         24  неоконченное высшее             2
#
#           family_status  family_status_id gender income_type  debt  \
# 10701  гражданский брак                 1    XNA   компаньон     0
#
#        total_income               purpose
# 10701     203905.16  покупка недвижимости

# %% [markdown]
# Пол этого заемщика не известен.

# %%
data['income_type'].value_counts()
# Out:
# сотрудник          11119
# компаньон           5085
# пенсионер           3856
# госслужащий         1459
# предприниматель        2
# безработный            2
# в декрете              1
# студент                1
# Name: income_type, dtype: int64

# %%
data['debt'].value_counts()
# Out:
# 0    19784
# 1     1741
# Name: debt, dtype: int64

# %%
print('total_income max =',data['total_income'].max())
print('total_income min =',data['total_income'].min())
print('total_income median =',data['total_income'].median())
# Out:
# total_income max = 2265604.03
# total_income min = 0.0
# total_income median = 135514.71

# %% [markdown]
# Наблюдается выброс по зарплате и так же присутствуют потери данных в виде нулевых значений.

# %%
data['purpose'].value_counts()
# Out:
# свадьба                                   797
# на проведение свадьбы                     777
# сыграть свадьбу                           774
# операции с недвижимостью                  676
# покупка коммерческой недвижимости         664
# покупка жилья для сдачи                   653
# операции с жильем                         653
# операции с коммерческой недвижимостью     651
# жилье                                     647
# покупка жилья                             647
# покупка жилья для семьи                   641
# строительство собственной недвижимости    635
# недвижимость                              634
# операции со своей недвижимостью           630
# строительство жилой недвижимости          626
# покупка недвижимости                      624
# строительство недвижимости                620
# покупка своего жилья                      620
# ремонт жилью                              612
# покупка жилой недвижимости                607
# на покупку своего автомобиля              505
# заняться высшим образованием              496
# автомобиль                                495
# сделка с подержанным автомобилем          489
# свой автомобиль                           480
# на покупку подержанного автомобиля        479
# автомобили                                478
# на покупку автомобиля                     472
# приобретение автомобиля                   462
# дополнительное образование                462
# сделка с автомобилем                      455
# высшее образование                        453
# получение дополнительного образования     447
# образование                               447
# получение образования                     443
# профильное образование                    436
# получение высшего образования             426
# заняться образованием                     412
# Name: purpose, dtype: int64

# %% [markdown]
# ### Вывод

# %% [markdown]
# Проведенных исследования по всем столбцам.
# Заполнены значения по трудовому стажу и зарплате, в данный момент на нулевые значения.
# Предположительно вывод был искажен из-за неверных настроек регистратора.
# По остальным столбцам были обнаружены нарушения регистра, не стандартный возраст, пол и зарплата заемшиков.
# Столбец с целями кредита требует лемматизации по значениям, поскольку имеет по разному сформулированные сходные категории.

# %% [markdown]
# ### Замена типа данных

# %% [markdown]
# Оценим записи с отрицательным количеством детей.

# %%
data[data['children']<0]
# Out:
#        children  days_employed  dob_years            education  education_id  \
# 291          -1           4417         46              среднее             1
# 705          -1            902         50              среднее             1
# 742          -1           3174         57              среднее             1
# 800          -1         349987         54              среднее             1
# 941          -1              0         57              среднее             1
# 1363         -1           1195         55              среднее             1
# 1929         -1           1461         38              среднее             1
# 2073         -1           2539         42              среднее             1
# 3814         -1           3045         26              среднее             1
# 4201         -1            901         41              среднее             1
# 4402         -1         398001         64              среднее             1
# 4542         -1           1811         32              среднее             1
# 5272         -1           1143         46              среднее             1
# 6013         -1           1361         46               высшее             0
# 6385         -1         370215         48              среднее             1
# 7190         -1           5928         34              среднее             1
# 7278         -1            526         51              среднее             1
# 7615         -1              0         35              среднее             1
# 7685         -1           3237         53              среднее             1
# 8229         -1           1803         54               высшее             0
# 8251         -1           3113         31              среднее             1
# 8561         -1            195         31              среднее             1
# 9565         -1           2896         34               высшее             0
# 9574         -1           2710         28               высшее             0
# 10177        -1           1743         37              среднее             1
# 10365        -1         345774         63               высшее             0
# 10918        -1         340499         50              среднее             1
# 11109        -1           3438         59              среднее             1
# 11268        -1           1048         30               высшее             0
# 11617        -1            370         27              среднее             1
# 12304        -1           8493         61  неоконченное высшее             2
# 13786        -1              0         42              среднее             1
# 14357        -1            268         23              среднее             1
# 15147        -1           9851         44              среднее             1
# 15435        -1           3614         40               высшее             0
# 16129        -1            457         33              среднее             1
# 16265        -1           2802         40               высшее             0
# 17095        -1           2809         34              среднее             1
# 17429        -1            895         37              среднее             1
# 17657        -1           4571         41              среднее             1
# 18219        -1           3575         33              среднее             1
# 19100        -1            617         38              среднее             1
# 19366        -1            372         43              среднее             1
# 19417        -1         350340         28              среднее             1
# 20393        -1         355157         69              среднее             1
# 20717        -1            661         32               высшее             0
# 21140        -1           1422         44              среднее             1
#
#                family_status  family_status_id gender  income_type  debt  \
# 291         гражданский брак                 1      F    сотрудник     0
# 705          женат / замужем                 0      F  госслужащий     0
# 742          женат / замужем                 0      F    сотрудник     0
# 800    не женат / не замужем                 4      F    пенсионер     0
# 941          женат / замужем                 0      F    пенсионер     0
# 1363         женат / замужем                 0      F    компаньон     0
# 1929   не женат / не замужем                 4      M    сотрудник     0
# 2073               в разводе                 3      F    компаньон     0
# 3814        гражданский брак                 1      F  госслужащий     0
# 4201         женат / замужем                 0      F  госслужащий     0
# 4402         женат / замужем                 0      F    пенсионер     0
# 4542         женат / замужем                 0      F    сотрудник     0
# 5272          вдовец / вдова                 2      F    сотрудник     0
# 6013         женат / замужем                 0      F    сотрудник     0
# 6385          вдовец / вдова                 2      F    пенсионер     0
# 7190         женат / замужем                 0      M    сотрудник     0
# 7278         женат / замужем                 0      F    сотрудник     0
# 7615         женат / замужем                 0      M    сотрудник     0
# 7685          вдовец / вдова                 2      F    сотрудник     0
# 8229         женат / замужем                 0      F    компаньон     0
# 8251        гражданский брак                 1      F    сотрудник     0
# 8561         женат / замужем                 0      F    сотрудник     0
# 9565         женат / замужем                 0      M    сотрудник     0
# 9574         женат / замужем                 0      M  госслужащий     0
# 10177        женат / замужем                 0      M    сотрудник     0
# 10365         вдовец / вдова                 2      F    пенсионер     0
# 10918        женат / замужем                 0      M    пенсионер     0
# 11109        женат / замужем                 0      F    сотрудник     0
# 11268       гражданский брак                 1      F    компаньон     0
# 11617        женат / замужем                 0      F    компаньон     0
# 12304        женат / замужем                 0      M    сотрудник     0
# 13786  не женат / не замужем                 4      M    компаньон     0
# 14357              в разводе                 3      F    компаньон     0
# 15147              в разводе                 3      F    сотрудник     0
# 15435       гражданский брак                 1      F    сотрудник     0
# 16129        женат / замужем                 0      F    сотрудник     1
# 16265        женат / замужем                 0      M    сотрудник     0
# 17095        женат / замужем                 0      F    сотрудник     0
# 17429        женат / замужем                 0      F    компаньон     0
# 17657        женат / замужем                 0      F    сотрудник     0
# 18219        женат / замужем                 0      F    сотрудник     0
# 19100  не женат / не замужем                 4      M    сотрудник     0
# 19366        женат / замужем                 0      M    сотрудник     0
# 19417              в разводе                 3      F    пенсионер     0
# 20393  не женат / не замужем                 4      F    пенсионер     0
# 20717        женат / замужем                 0      F    сотрудник     0
# 21140        женат / замужем                 0      F    компаньон     0
#
#        total_income                                 purpose
# 291       102816.35                  профильное образование
# 705       137882.90                 приобретение автомобиля
# 742        64268.04              дополнительное образование
# 800        86293.72              дополнительное образование
# 941            0.00            на покупку своего автомобиля
# 1363       69550.70                  профильное образование
# 1929      109121.57                           покупка жилья
# 2073      162638.61                           покупка жилья
# 3814      131892.79                   на проведение свадьбы
# 4201      226375.77         операции со своей недвижимостью
# 4402      163264.06                    покупка недвижимости
# 4542      160544.72                             образование
# 5272      278708.02                    покупка недвижимости
# 6013      143008.45  строительство собственной недвижимости
# 6385       36052.45                             образование
# 7190      184315.12                 приобретение автомобиля
# 7278      146928.77   операции с коммерческой недвижимостью
# 7615           0.00                             образование
# 7685      159676.17        строительство жилой недвижимости
# 8229      138809.08                    покупка недвижимости
# 8251       54412.06                         свой автомобиль
# 8561      145577.88                            ремонт жилью
# 9565      126754.66                операции с недвижимостью
# 9574      303137.16   получение дополнительного образования
# 10177     310367.51                   получение образования
# 10365     170762.75        строительство жилой недвижимости
# 10918     170762.77                    покупка своего жилья
# 11109     219874.01                       операции с жильем
# 11268     321603.70                   на покупку автомобиля
# 11617     164591.26                 покупка жилья для сдачи
# 12304     315006.18                            недвижимость
# 13786          0.00                              автомобиль
# 14357      92257.58              покупка жилой недвижимости
# 15147     110990.81                         свой автомобиль
# 15435      98127.54                         сыграть свадьбу
# 16129     149641.08                              автомобиль
# 16265     111984.47                           покупка жилья
# 17095     182543.89      на покупку подержанного автомобиля
# 17429     214814.02                                   жилье
# 17657     122105.42         операции со своей недвижимостью
# 18219     128362.02                      высшее образование
# 19100     122205.50        строительство жилой недвижимости
# 19366     155588.77        сделка с подержанным автомобилем
# 19417      52872.99                              автомобили
# 20393     116521.05                операции с недвижимостью
# 20717     137405.38              покупка жилой недвижимости
# 21140     169562.09         операции со своей недвижимостью

# %% [markdown]
# Предположительно значением "-1" так же обозначалось отсутсвие детей.
# Заменим это значение на "0".

# %%
data['children'] = data['children'].replace(-1,0)

# %%
data['children'].value_counts()
# Out:
# 0     14196
# 1      4818
# 2      2055
# 3       330
# 20       76
# 4        41
# 5         9
# Name: children, dtype: int64

# %% [markdown]
# Рассмотрим теперь позиции с детьми больше 5.

# %%
data[data['children']>5].sort_values(by='days_employed')
# Out:
#        children  days_employed  dob_years education  education_id  \
# 21390        20              0         53   среднее             1
# 19774        20              0         59   среднее             1
# 3302         20              0         35   среднее             1
# 3396         20              0         56    высшее             0
# 6198         20              0         35    высшее             0
# ...         ...            ...        ...       ...           ...
# 5362         20         355898         69   среднее             1
# 7789         20         360485         55   среднее             1
# 5349         20         361744         64   среднее             1
# 14355        20         378510         56   среднее             1
# 13489        20         385267         62   среднее             1
#
#                family_status  family_status_id gender  income_type  debt  \
# 21390        женат / замужем                 0      M    компаньон     0
# 19774       гражданский брак                 1      F    пенсионер     0
# 3302   не женат / не замужем                 4      F  госслужащий     0
# 3396         женат / замужем                 0      F    компаньон     0
# 6198   не женат / не замужем                 4      M    компаньон     0
# ...                      ...               ...    ...          ...   ...
# 5362         женат / замужем                 0      M    пенсионер     0
# 7789         женат / замужем                 0      F    пенсионер     0
# 5349          вдовец / вдова                 2      F    пенсионер     0
# 14355        женат / замужем                 0      F    пенсионер     0
# 13489       гражданский брак                 1      F    пенсионер     0
#
#        total_income                                 purpose
# 21390          0.00              покупка жилой недвижимости
# 19774          0.00                         сыграть свадьбу
# 3302           0.00                  профильное образование
# 3396           0.00                      высшее образование
# 6198           0.00                                   жилье
# ...             ...                                     ...
# 5362      138579.08                              автомобили
# 7789      138626.76  строительство собственной недвижимости
# 5349       81926.82                       операции с жильем
# 14355     127947.13        сделка с подержанным автомобилем
# 13489     192221.08   операции с коммерческой недвижимостью
#
# [76 rows x 12 columns]

# %%
child_mod_median = (data['children']<=5).median()
child_mod_median
# Out:
# 1.0

# %% [markdown]
# Определив медиану заменим значение в 20 детей на медианальное.

# %%
data['children'] = data['children'].replace(20, child_mod_median)
data[data['children']> 5]
# Out:
# Empty DataFrame
# Columns: [children, days_employed, dob_years, education, education_id, family_status, family_status_id, gender, income_type, debt, total_income, purpose]
# Index: []

# %% [markdown]
# Позиций где детей больше 5 больше нет.

# %%
data[data['dob_years']< 1]
# Out:
#        children  days_employed  dob_years education  education_id  \
# 99            0         346541          0   среднее             1
# 149           0           2664          0   среднее             1
# 270           3           1872          0   среднее             1
# 578           0         397856          0   среднее             1
# 1040          0           1158          0    высшее             0
# ...         ...            ...        ...       ...           ...
# 19829         0              0          0   среднее             1
# 20462         0         338734          0   среднее             1
# 20577         0         331741          0   среднее             1
# 21179         2            108          0    высшее             0
# 21313         0           1268          0   среднее             1
#
#                family_status  family_status_id gender income_type  debt  \
# 99           женат / замужем                 0      F   пенсионер     0
# 149                в разводе                 3      F   сотрудник     0
# 270          женат / замужем                 0      F   сотрудник     0
# 578          женат / замужем                 0      F   пенсионер     0
# 1040               в разводе                 3      F   компаньон     0
# ...                      ...               ...    ...         ...   ...
# 19829        женат / замужем                 0      F   сотрудник     0
# 20462        женат / замужем                 0      F   пенсионер     0
# 20577  не женат / не замужем                 4      F   пенсионер     0
# 21179        женат / замужем                 0      M   компаньон     0
# 21313  не женат / не замужем                 4      M   сотрудник     0
#
#        total_income                                 purpose
# 99         71291.52                              автомобиль
# 149        70176.44                       операции с жильем
# 270       102166.46                            ремонт жилью
# 578        97620.69  строительство собственной недвижимости
# 1040      303994.13                         свой автомобиль
# ...             ...                                     ...
# 19829          0.00                                   жилье
# 20462     259193.92                    покупка своего жилья
# 20577     129788.76                            недвижимость
# 21179     240702.01        строительство жилой недвижимости
# 21313     152419.18                       операции с жильем
#
# [101 rows x 12 columns]

# %% [markdown]
# Заменим нулевой возраст на медианное округленное значение.

# %%
dob_years_median = data['dob_years'].median()
data['dob_years'] = data['dob_years'].replace(0, dob_years_median)
data[data['dob_years']<0]
# Out:
# Empty DataFrame
# Columns: [children, days_employed, dob_years, education, education_id, family_status, family_status_id, gender, income_type, debt, total_income, purpose]
# Index: []

# %% [markdown]
# Нулевые значения возраста отсутствуют.

# %%
data['gender'].value_counts()
# Out:
# F      14236
# M       7288
# XNA        1
# Name: gender, dtype: int64

# %% [markdown]
# Поскольку большинство заемщиков женского пола, предположим что потерянный пол тоже женский.

# %%
data['gender'] = data['gender'].replace('XNA','F')
data['gender'].value_counts()
# Out:
# F    14237
# M     7288
# Name: gender, dtype: int64

# %% [markdown]
# Определим моду по среднемесячной зарплате.

# %%
data['total_income'].sort_values().tail(50)
# Out:
# 15660     735103.27
# 9510      750240.01
# 39        754240.80
# 13440     757516.87
# 3996      758821.81
# 11478     773136.75
# 14213     786451.62
# 4740      812559.32
# 21295     816023.12
# 1858      818648.36
# 6645      822426.02
# 5044      829016.67
# 10199     841836.85
# 16533     853367.81
# 7893      858235.07
# 16189     859327.80
# 19303     862447.72
# 17177     866784.79
# 19302     868543.31
# 6483      900855.47
# 3097      910451.47
# 5289      920897.72
# 13926     958434.58
# 8299      967425.42
# 10613     997014.30
# 4129     1004476.45
# 9156     1006468.11
# 18347    1027742.28
# 4415     1030899.17
# 15047    1058193.47
# 1590     1089120.31
# 19338    1091627.59
# 18766    1092608.20
# 10004    1097954.74
# 9871     1103455.43
# 13090    1128836.26
# 15211    1172459.83
# 19813    1223042.48
# 7447     1240165.00
# 2224     1278622.61
# 11071    1286281.00
# 15268    1350245.61
# 18353    1427934.46
# 18368    1551152.89
# 17503    1597613.49
# 17178    1711309.27
# 20809    1715018.39
# 9169     1726276.01
# 19606    2200852.21
# 12412    2265604.03
# Name: total_income, dtype: float64

# %% [markdown]
# Верхняя граница представляется равномерной.

# %%
(data['total_income']==0).sum()
# Out:
# 2174

# %% [markdown]
# Поскольку столбец ежемесячных доходов представляется более-менее равномерным, выделим средний арифметический показатель и применим ко всем нулевым значениям.

# %%
zero_income = data[data['total_income']>0]
income_mean = round(zero_income['total_income'].mean(),2)
income_mean
data['total_income'] = data['total_income'].replace(0, income_mean)

# %%
data[data['total_income']==0]
# Out:
# Empty DataFrame
# Columns: [children, days_employed, dob_years, education, education_id, family_status, family_status_id, gender, income_type, debt, total_income, purpose]
# Index: []

# %% [markdown]
# ### Вывод

# %% [markdown]
# Возможные ошибки исправлены и пропущенные значения приведены к медианным или средним показателям.
# Последний столбец будет обработан в части "Лемматизация".

# %% [markdown]
# ### Обработка дубликатов

# %%
data.duplicated().sum()
# Out:
# 72

# %%
data = data.drop_duplicates().reset_index(drop=True)
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Вывод

# %% [markdown]
# Во всей таблице, после преобразований были обнаружены 72 дубликата и удалены.
# Индексы переназначены.

# %% [markdown]
# ### Лемматизация

# %%
from pymystem3 import Mystem
m = Mystem()

# %% [markdown]
# Выделим перечень уникальных слов минуя пробелы и посчитаем их частоту.

# %%
all_words = []
unique_words = []
for row in data['purpose']:
    lemmas = m.lemmatize(row)
    for word in lemmas:
        if (word != ' ') and (word != '\n'):
            all_words.append(word)
for w in all_words:
    if w not in unique_words:
        unique_words.append(w)

print(unique_words)
print()
print(data['purpose'].unique())
# Out:
# ['покупка', 'жилье', 'приобретение', 'автомобиль', 'дополнительный', 'образование', 'сыграть', 'свадьба', 'операция', 'с', 'на', 'проведение', 'для', 'семья', 'недвижимость', 'коммерческий', 'жилой', 'строительство', 'собственный', 'подержать', 'свой', 'со', 'заниматься', 'сделка', 'подержанный', 'получение', 'высокий', 'профильный', 'сдача', 'ремонт']
#
# ['покупка жилья' 'приобретение автомобиля' 'дополнительное образование'
#  'сыграть свадьбу' 'операции с жильем' 'образование'
#  'на проведение свадьбы' 'покупка жилья для семьи' 'покупка недвижимости'
#  'покупка коммерческой недвижимости' 'покупка жилой недвижимости'
#  'строительство собственной недвижимости' 'недвижимость'
#  'строительство недвижимости' 'на покупку подержанного автомобиля'
#  'на покупку своего автомобиля' 'операции с коммерческой недвижимостью'
#  'строительство жилой недвижимости' 'жилье'
#  'операции со своей недвижимостью' 'автомобили' 'заняться образованием'
#  'сделка с подержанным автомобилем' 'получение образования' 'автомобиль'
#  'свадьба' 'получение дополнительного образования' 'покупка своего жилья'
#  'операции с недвижимостью' 'получение высшего образования'
#  'свой автомобиль' 'сделка с автомобилем' 'профильное образование'
#  'высшее образование' 'покупка жилья для сдачи' 'на покупку автомобиля'
#  'ремонт жилью' 'заняться высшим образованием']

# %% [markdown]
# ### Вывод

# %% [markdown]
# * Мы выделили все возможные леммы из нашего же перечня, для минимизации ошибок и потери времени на подборе верных категорий.
# * Сравнили полученные уникальные леммы и уникальные значения в целях кредита.
# * P.S. Можно было, похоже, через класс Counter добыть уникальные значения вызывая ключи словаря, но эта идея потребует подключения дополнительной библиотеки и возможных трудностей.

# %% [markdown]
# ### Категоризация данных

# %% [markdown]
# Сравнив список лемматизатора и уникальных позиций сформируем список с категориями.

# %%
PURPOSE_CATEGORY = ('жилье', 'автомобиль', 'образование', 'свадьба', 'недвижимость')
def categorize (row):
    purpose = row['purpose']
    lemmas = m.lemmatize(purpose)
    for lemma in lemmas:
        if lemma in PURPOSE_CATEGORY:
            return lemma

# %% [markdown]
# Проверим функцию перед категоризацией по леммам.

# %%
row_value = ['сыграть свадьбу']
row_column = ['purpose']
row = pd.Series(data=row_value, index=row_column)
print(categorize(row))
# Out:
# свадьба

# %% [markdown]
# Создадим новый столбец с разделением на категории по цели кредита.

# %%
data['purpose_category'] = data.apply(categorize, axis=1)

# %% [markdown]
# Простетируем вывод и посчитаем количество элементов.

# %%
data.head(10)
# Out:
#    children  days_employed  dob_years education  education_id  \
# 0         1           8437         42    высшее             0
# 1         1           4024         36   среднее             1
# 2         0           5623         33   среднее             1
# 3         3           4124         32   среднее             1
# 4         0         340266         53   среднее             1
# 5         0            926         27    высшее             0
# 6         0           2879         43    высшее             0
# 7         0            152         50   среднее             1
# 8         2           6929         35    высшее             0
# 9         0           2188         41   среднее             1
#
#       family_status  family_status_id gender income_type  debt  total_income  \
# 0   женат / замужем                 0      F   сотрудник     0     253875.64
# 1   женат / замужем                 0      F   сотрудник     0     112080.01
# 2   женат / замужем                 0      M   сотрудник     0     145885.95
# 3   женат / замужем                 0      M   сотрудник     0     267628.55
# 4  гражданский брак                 1      F   пенсионер     0     158616.08
# 5  гражданский брак                 1      M   компаньон     0     255763.57
# 6   женат / замужем                 0      F   компаньон     0     240525.97
# 7   женат / замужем                 0      M   сотрудник     0     135823.93
# 8  гражданский брак                 1      F   сотрудник     0      95856.83
# 9   женат / замужем                 0      M   сотрудник     0     144425.94
#
#                       purpose purpose_category
# 0               покупка жилья            жилье
# 1     приобретение автомобиля       автомобиль
# 2               покупка жилья            жилье
# 3  дополнительное образование      образование
# 4             сыграть свадьбу          свадьба
# 5               покупка жилья            жилье
# 6           операции с жильем            жилье
# 7                 образование      образование
# 8       на проведение свадьбы          свадьба
# 9     покупка жилья для семьи            жилье

# %%
data['purpose_category'].value_counts()
# Out:
# недвижимость    6351
# жилье           4460
# автомобиль      4306
# образование     4013
# свадьба         2323
# Name: purpose_category, dtype: int64

# %% [markdown]
# Сформируем категории по зарплате:

# %%
def income_categorize(row):
    income=row['total_income']
    if income < 25000:
        return 'меньше 25000'
    elif 25000 <= income <50000:
        return 'от 25 тыс. до 50 тыс.'
    elif 50000 <= income < 100000:
        return 'от 50 тыс. до 100 тыс.'
    elif 100000 <= income <200000:
        return 'от 100 тыс. до 200 тыс.'
    elif 200000 <= income <500000:
        return 'от 200 тыс. до 500 тыс.'
    elif 500000 <= income <1000000:
        return 'от 500 тыс. до 1 млн.'
    elif income > 1000000:
        return 'от 1 млн. и выше'
    else:
        return 'NaN'

# %% [markdown]
# Проверим функцию:

# %%
inc_value = [45643]
inc_column = ['total_income']
inc = pd.Series(data=inc_value, index=inc_column)
print(income_categorize(inc))
# Out:
# от 25 тыс. до 50 тыс.

# %%
data['income_groups'] = data.apply(income_categorize, axis=1)
data.head(10)
# Out:
#    children  days_employed  dob_years education  education_id  \
# 0         1           8437         42    высшее             0
# 1         1           4024         36   среднее             1
# 2         0           5623         33   среднее             1
# 3         3           4124         32   среднее             1
# 4         0         340266         53   среднее             1
# 5         0            926         27    высшее             0
# 6         0           2879         43    высшее             0
# 7         0            152         50   среднее             1
# 8         2           6929         35    высшее             0
# 9         0           2188         41   среднее             1
#
#       family_status  family_status_id gender income_type  debt  total_income  \
# 0   женат / замужем                 0      F   сотрудник     0     253875.64
# 1   женат / замужем                 0      F   сотрудник     0     112080.01
# 2   женат / замужем                 0      M   сотрудник     0     145885.95
# 3   женат / замужем                 0      M   сотрудник     0     267628.55
# 4  гражданский брак                 1      F   пенсионер     0     158616.08
# 5  гражданский брак                 1      M   компаньон     0     255763.57
# 6   женат / замужем                 0      F   компаньон     0     240525.97
# 7   женат / замужем                 0      M   сотрудник     0     135823.93
# 8  гражданский брак                 1      F   сотрудник     0      95856.83
# 9   женат / замужем                 0      M   сотрудник     0     144425.94
#
#                       purpose purpose_category            income_groups
# 0               покупка жилья            жилье  от 200 тыс. до 500 тыс.
# 1     приобретение автомобиля       автомобиль  от 100 тыс. до 200 тыс.
# 2               покупка жилья            жилье  от 100 тыс. до 200 тыс.
# 3  дополнительное образование      образование  от 200 тыс. до 500 тыс.
# 4             сыграть свадьбу          свадьба  от 100 тыс. до 200 тыс.
# 5               покупка жилья            жилье  от 200 тыс. до 500 тыс.
# 6           операции с жильем            жилье  от 200 тыс. до 500 тыс.
# 7                 образование      образование  от 100 тыс. до 200 тыс.
# 8       на проведение свадьбы          свадьба   от 50 тыс. до 100 тыс.
# 9     покупка жилья для семьи            жилье  от 100 тыс. до 200 тыс.

# %%
data['income_groups'].value_counts()
# Out:
# от 100 тыс. до 200 тыс.    11924
# от 200 тыс. до 500 тыс.     4844
# от 50 тыс. до 100 тыс.      4091
# от 25 тыс. до 50 тыс.        364
# от 500 тыс. до 1 млн.        197
# от 1 млн. и выше              25
# меньше 25000                   8
# Name: income_groups, dtype: int64

# %% [markdown]
# ### Вывод

# %% [markdown]
# Сформированы категории по потребностям кредита, что позволит более обще группировать индивидуальные записи.
# * Самое большое количество кредитов берется на действия с недвижимостью
# * Меньше всего люди берут займы на свадьбу
#
# Так же мы сформировали категории по зарплате, что позволит выделить группы и определить процент возвращаемых в срок заемных средств.

# %% [markdown]
# ### Шаг 3. Ответьте на вопросы

# %% [markdown]
# #### Есть ли зависимость между наличием детей и возвратом кредита в срок?

# %%
def debt_pivot(df, index):
    pivot = df.pivot_table(index=index, values='debt', aggfunc=['count','sum', 'mean'])
    pivot['mean'] = pivot['mean'].mul(100).round(1).astype(str) + '%'
    return pivot.sort_values(by=('mean','debt'), ascending=False)

# %%
debt_pivot(data, 'children')
# Out:
#           count   sum  mean
#            debt  debt  debt
# children
# 4            41     4  9.8%
# 2          2052   194  9.5%
# 1          4884   452  9.3%
# 3           330    27  8.2%
# 0         14137  1064  7.5%
# 5             9     0  0.0%

# %% [markdown]
# ### Вывод

# %% [markdown]
# Да, присутствует некоторая зависимость возврата задолженности от количества детей.
# * Исходя из показателей процентного соотношения количества должников реже всего возвращают деньги в срок заемщики, у которых большее количество детей.
# * Самый высокий процент возврата долгов показали бездетные семьи.
# * Результаты по семьям с 5ю детьми не показательны, так как мало данных.

# %% [markdown]
# #### Есть ли зависимость между семейным положением и возвратом кредита в срок?

# %%
debt_pivot(data, 'family_status')
# Out:
#                        count  sum  mean
#                         debt debt  debt
# family_status
# не женат / не замужем   2810  274  9.8%
# гражданский брак        4150  388  9.3%
# женат / замужем        12339  931  7.5%
# в разводе               1195   85  7.1%
# вдовец / вдова           959   63  6.6%

# %% [markdown]
# ### Вывод

# %% [markdown]
# Некоторая зависимость между семейным положением и возвратом кредита в срок так же наблюдается.
# * Самыми неблагонадежными заемщиками оказались холостые клиенты.
# * А чаще всего возвращают заемные средства в срок вдовцы/вдовы и клиенты в разводе.

# %% [markdown]
# #### Есть ли зависимость между уровнем дохода и возвратом кредита в срок?

# %%
debt_pivot(data,'income_groups')
# Out:
#                          count   sum   mean
#                           debt  debt   debt
# income_groups
# от 100 тыс. до 200 тыс.  11924  1029   8.6%
# от 50 тыс. до 100 тыс.    4091   331   8.1%
# от 1 млн. и выше            25     2   8.0%
# от 200 тыс. до 500 тыс.   4844   344   7.1%
# от 500 тыс. до 1 млн.      197    12   6.1%
# от 25 тыс. до 50 тыс.      364    22   6.0%
# меньше 25000                 8     1  12.5%

# %% [markdown]
# ### Вывод

# %% [markdown]
# * Самой неблагонадежной согласно нашим исследованиям оказывается группа с зарплатой от 100 до 200 тыс. рублей.
# * Наоборот примечателен факт что самыми благонадежными оказываются группы с самым скромным достатком и с приличным достатком до 1 млн. руб. в месяц.
# * Отдельно отметим группу от 1 млн. и выше - у людей с такой зарплатой отношение к деньгам уже совсем иное.

# %% [markdown]
# #### Как разные цели кредита влияют на его возврат в срок?

# %%
debt_pivot(data,'purpose_category')
# Out:
#                  count  sum  mean
#                   debt debt  debt
# purpose_category
# автомобиль        4306  403  9.4%
# образование       4013  370  9.2%
# свадьба           2323  186  8.0%
# недвижимость      6351  474  7.5%
# жилье             4460  308  6.9%

# %% [markdown]
# ### Вывод

# %% [markdown]
# Да, зависимость присутствует.
# * согласно исследованию самые не благонадежные клиенты те, которые берут кредит на автомобиль.
# * напротив чаще вовзращают средства в срок кредиты, взятые на операции с жильем.

# %% [markdown]
# ### Шаг 4. Общий вывод

# %% [markdown]
# Самый неблагонадежный заемщик выглядит следующим образом:
# * у него 2 и более детей
# * не женат/не замужем
# * с зарплатой от 100 до 200 тыс. рублей
# * который собирается покупать автомобиль или получать образование
#
# Складывается образ успешного алиментщика.

# %% [markdown]
# Самый же надежный кредитодержатель выглядит так:
# * у него нет детей
# * вдовец/вдова или в разводе
# * зарабатывает либо меньше 50 тыс. рублей либо от 500 до 1 млн. рублей
# * и собирается на заемные средства приобретать жилье
#
# Кажется что это творческий человек (художник, скульптор, музыкант и т.п.)
